# C:\Users\sridu\Desktop\mba\.ipynb_checkpoints\onlineap-checkpoint.ipynb
# C:\Users\sridu\Desktop\mba\.ipynb_checkpoints\storedata-checkpoint.ipynb

# %%
data = pd.read_csv(r'C:\Users\sridu\Desktop\mba\Hackathon_Working_Data.csv')

# %%
print('There are {} distinct data at Group level'.format(data['GRP'].nunique()))
print('There are {} distinct data at sub-Group level'.format(data['SGRP'].nunique()))
print('There are {} distinct data at sub-sub-Group level'.format(data['SSGRP'].nunique()))
print('There are {} distinct data at Company level'.format(data['CMP'].nunique()))
print('There are {} distinct data at Mother-Brand level'.format(data['MBRD'].nunique()))
print('There are {} distinct data at Brand level'.format(data['BRD'].nunique()))
# Out:
# There are 80 distinct data at Group level
# There are 177 distinct data at sub-Group level
# There are 242 distinct data at sub-sub-Group level
# There are 512 distinct data at Company level
# There are 818 distinct data at Mother-Brand level
# There are 1613 distinct data at Brand level

# %%
data_N1 = data[data['STORECODE'] == 'N1']
print(data_N1.shape)
# Out:
# (4583, 14)

# %%
data_N1 = data_N1[['BILL_ID', 'QTY', 'GRP']]

# %%
basket = data_N1.groupby(['BILL_ID', 'GRP'])['QTY'].sum().unstack().reset_index().fillna(0).set_index('BILL_ID')

# %%
def encode_unit(x):
    if x <= 0:
        return 0
    if x >= 0:
        return 1
    
encoded_data = basket.applymap(encode_unit)

# %%
frequent_items = apriori(encoded_data, min_support = 0.01, use_colnames = True)

# %%
rules = association_rules(frequent_items, metric = 'lift', min_threshold = 0)

# %%
store = list(data['STORECODE'].unique())
store
# Out:
# ['N1', 'N2', 'N3', 'N4', 'N5', 'N6', 'N7', 'N8', 'N9', 'N10']

# %%
for i in range(0,len(store)):
    data_N = data[data['STORECODE'] == store[i]]
    data_N = data_N[['BILL_ID', 'QTY', 'GRP']]
    
    basket = data_N.groupby(['BILL_ID', 'GRP'])['QTY'].sum().unstack().reset_index().fillna(0).set_index('BILL_ID')
    
    def encode_unit(x):
        if x <= 0:
            return 0
        if x >= 0:
            return 1
    
    encoded_data = basket.applymap(encode_unit)
    frequent_items = apriori(encoded_data, min_support = 0.01, use_colnames = True)
    
    rules = association_rules(frequent_items, metric = 'lift', min_threshold = 0)
    
    rules.to_csv('AssociationRuleforstore{}.csv'.format(store[i]))

# %%
rules
# Out:
#                         antecedents                      consequents  \
# 0                (ALL IODISED SALT)     (BISCUITS - CORE & NON CORE)
# 1      (BISCUITS - CORE & NON CORE)               (ALL IODISED SALT)
# 2                    (PACKAGED TEA)               (ALL IODISED SALT)
# 3                (ALL IODISED SALT)                   (PACKAGED TEA)
# 4               (BREAKFAST CEREALS)     (BISCUITS - CORE & NON CORE)
# 5      (BISCUITS - CORE & NON CORE)              (BREAKFAST CEREALS)
# 6            (BUTTER MARGR  (4/94))     (BISCUITS - CORE & NON CORE)
# 7      (BISCUITS - CORE & NON CORE)           (BUTTER MARGR  (4/94))
# 8            (CHEESE        (4/94))     (BISCUITS - CORE & NON CORE)
# 9      (BISCUITS - CORE & NON CORE)           (CHEESE        (4/94))
# 10                      (CHOCOLATE)     (BISCUITS - CORE & NON CORE)
# 11     (BISCUITS - CORE & NON CORE)                      (CHOCOLATE)
# 12                (KETCHUPS/SAUCES)     (BISCUITS - CORE & NON CORE)
# 13     (BISCUITS - CORE & NON CORE)                (KETCHUPS/SAUCES)
# 14           (PACKAGED ATTA (1/95))     (BISCUITS - CORE & NON CORE)
# 15     (BISCUITS - CORE & NON CORE)           (PACKAGED ATTA (1/95))
# 16                   (PACKAGED TEA)     (BISCUITS - CORE & NON CORE)
# 17     (BISCUITS - CORE & NON CORE)                   (PACKAGED TEA)
# 18  (REFINED EDIBLE OILS-ALL PACKS)     (BISCUITS - CORE & NON CORE)
# 19     (BISCUITS - CORE & NON CORE)  (REFINED EDIBLE OILS-ALL PACKS)
# 20            (SALTY SNACKS (2/97))     (BISCUITS - CORE & NON CORE)
# 21     (BISCUITS - CORE & NON CORE)            (SALTY SNACKS (2/97))
# 22                 (SPICES (03/04))     (BISCUITS - CORE & NON CORE)
# 23     (BISCUITS - CORE & NON CORE)                 (SPICES (03/04))
# 24                   (TOOTH PASTES)     (BISCUITS - CORE & NON CORE)
# 25     (BISCUITS - CORE & NON CORE)                   (TOOTH PASTES)
# 26            (VERMICELLI & NOODLE)     (BISCUITS - CORE & NON CORE)
# 27     (BISCUITS - CORE & NON CORE)            (VERMICELLI & NOODLE)
# 28  (REFINED EDIBLE OILS-ALL PACKS)           (PACKAGED ATTA (1/95))
# 29           (PACKAGED ATTA (1/95))  (REFINED EDIBLE OILS-ALL PACKS)
# 30                   (PACKAGED TEA)  (REFINED EDIBLE OILS-ALL PACKS)
# 31  (REFINED EDIBLE OILS-ALL PACKS)                   (PACKAGED TEA)
# 32                   (PACKAGED TEA)                 (SPICES (03/04))
# 33                 (SPICES (03/04))                   (PACKAGED TEA)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.072000            0.370667  0.022222    0.308642  0.832667
# 1             0.370667            0.072000  0.022222    0.059952  0.832667
# 2             0.081778            0.072000  0.010667    0.130435  1.811594
# 3             0.072000            0.081778  0.010667    0.148148  1.811594
# 4             0.047111            0.370667  0.013333    0.283019  0.763540
# 5             0.370667            0.047111  0.013333    0.035971  0.763540
# 6             0.080000            0.370667  0.018667    0.233333  0.629496
# 7             0.370667            0.080000  0.018667    0.050360  0.629496
# 8             0.040889            0.370667  0.010667    0.260870  0.703785
# 9             0.370667            0.040889  0.010667    0.028777  0.703785
# 10            0.104000            0.370667  0.035556    0.341880  0.922339
# 11            0.370667            0.104000  0.035556    0.095923  0.922339
# 12            0.051556            0.370667  0.015111    0.293103  0.790747
# 13            0.370667            0.051556  0.015111    0.040767  0.790747
# 14            0.088889            0.370667  0.017778    0.200000  0.539568
# 15            0.370667            0.088889  0.017778    0.047962  0.539568
# 16            0.081778            0.370667  0.017778    0.217391  0.586487
# 17            0.370667            0.081778  0.017778    0.047962  0.586487
# 18            0.062222            0.370667  0.015111    0.242857  0.655190
# 19            0.370667            0.062222  0.015111    0.040767  0.655190
# 20            0.075556            0.370667  0.024889    0.329412  0.888701
# 21            0.370667            0.075556  0.024889    0.067146  0.888701
# 22            0.081778            0.370667  0.016889    0.206522  0.557163
# 23            0.370667            0.081778  0.016889    0.045564  0.557163
# 24            0.018667            0.370667  0.010667    0.571429  1.541624
# 25            0.370667            0.018667  0.010667    0.028777  1.541624
# 26            0.067556            0.370667  0.016889    0.250000  0.674460
# 27            0.370667            0.067556  0.016889    0.045564  0.674460
# 28            0.062222            0.088889  0.012444    0.200000  2.250000
# 29            0.088889            0.062222  0.012444    0.140000  2.250000
# 30            0.081778            0.062222  0.010667    0.130435  2.096273
# 31            0.062222            0.081778  0.010667    0.171429  2.096273
# 32            0.081778            0.081778  0.012444    0.152174  1.860822
# 33            0.081778            0.081778  0.012444    0.152174  1.860822
#
#     leverage  conviction
# 0  -0.004466    0.910286
# 1  -0.004466    0.987184
# 2   0.004779    1.067200
# 3   0.004779    1.077913
# 4  -0.004129    0.877754
# 5  -0.004129    0.988444
# 6  -0.010987    0.820870
# 7  -0.010987    0.968788
# 8  -0.004489    0.851451
# 9  -0.004489    0.987529
# 10 -0.002994    0.956260
# 11 -0.002994    0.991066
# 12 -0.003999    0.890276
# 13 -0.003999    0.988753
# 14 -0.015170    0.786667
# 15 -0.015170    0.957011
# 16 -0.012535    0.804148
# 17 -0.012535    0.964480
# 18 -0.007953    0.831195
# 19 -0.007953    0.977633
# 20 -0.003117    0.938480
# 21 -0.003117    0.990985
# 22 -0.013423    0.793132
# 23 -0.013423    0.962057
# 24  0.003748    1.468444
# 25  0.003748    1.010410
# 26 -0.008152    0.839111
# 27 -0.008152    0.976958
# 28  0.006914    1.138889
# 29  0.006914    1.090439
# 30  0.005578    1.078444
# 31  0.005578    1.108199
# 32  0.005757    1.083031
# 33  0.005757    1.083031

# %%
AssociationRuleforstore1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b2006dcac3ba> in <module>
# ----> 1 AssociationRuleforstore1
#
# NameError: name 'AssociationRuleforstore1' is not defined

# %%
AssociationRuleforstore{1}
# Out:
#   File "<ipython-input-19-cce7b2493b5a>", line 1
#     AssociationRuleforstore{1}
#                            ^
# SyntaxError: invalid syntax
